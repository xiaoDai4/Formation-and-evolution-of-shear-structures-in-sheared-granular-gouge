# %%
#%% import pakages
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#  set parameters

#  work path
wd_ = 'C:/Users/daizh/sheared_granular_gouge/20231116_FifthRun3/PythonFile_CalculateGranularQuantity'

path_FrictionState_ = '../particle_info/particle_info_friction_state.txt'
path_ParticleInfo_ = '../particle_info/particle_info_%d.txt' # note this path need to replace the number
path_HistoryData_ = '../particle_info/history_data.his'

#%% change current directory
os.chdir(wd_)
# import function
from import_data import *

# %%
#%% read FrictionState and HistoryData
# table head: 0. Load pointer displacement, 1. Friction, 2. Top plate displacement, 
# 3. Bottom plate displacement, 4. Top plate velocity, 5. Bottom plate velocity
FrictionState_ = read_FrictionState(path_FrictionState_)
# table head: 0. step, 1. displacement, 2. gouge_thickness, 3. shear_strain,
# 4. shear_stress, 5. normal_stress, 6. friction,  7. plate_displacement,
# 8. plate_velocity, 9. plate_displacement_bottom, 10. plate_velocity_bottom,
# 11. shear_strain_rate
HistoryData_ = read_HistoryData(path_HistoryData_)
# Out:
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
#        ' Bottom plate velocity'],
#       dtype='object')
#
# Read friction state successful
#
#
# Reading history data...
#
#          Step displaceme... gouge_thic... shear_stra... shear_stre... normal_str... friction (... plate_disp... plate_velo... plate_disp... plate_velo... shear_stra...
#
#
# Read history data successful

# %%
# friction overall

plt.rcParams['font.size'] = 12
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(HistoryData_[:, 1] * 1000,  \
         HistoryData_[:, 6],\
         linewidth = 1, color = 'b')
plt.xlim([-0.1, 4])
plt.ylim([-0.01, 0.35])
plt.xlabel('Displacement (mm)', fontsize = 14)
plt.ylabel('Macro friction coefficient', fontsize = 14)
plt.tight_layout()
plt.savefig('note_book_plot/friction overall.svg', dpi=600, format='svg')
plt.show()

# %%
# friction inset linear stage
fig = plt.figure(figsize=(6*0.5,4*0.5))
plt.rcParams['font.size'] = 12
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(HistoryData_[:, 1] * 1000,  \
         HistoryData_[:, 6],\
         linewidth = 1, color = 'b')
plt.xticks([0.005,0.095, 0.185])
plt.yticks([0, 0.05, 0.1, 0.15])
plt.xlim([0.005, 0.185])
plt.ylim([0, 0.15])

# plt.xlabel('Displacement (mm)', fontsize = 19)
# plt.ylabel('Macro friction coefficient', fontsize = 19)
plt.tight_layout()
plt.savefig('note_book_plot/friction inset linear stage.svg', dpi=600, format='svg')
plt.show()

# %%
# friction inset yield stage 
fig = plt.figure(figsize=(6*0.5,4*0.5))
plt.rcParams['font.size'] = 12
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(HistoryData_[:, 1] * 1000,  \
         HistoryData_[:, 6],\
         linewidth = 1, color = 'b')
plt.xlim([0.25, 0.43])
plt.ylim([0.15, 0.30])
plt.xticks([0.25, 0.34, 0.43])
plt.yticks([0.15, 0.20, 0.25, 0.30])


# plt.xlabel('Displacement (mm)', fontsize = 19)
# plt.ylabel('Macro friction coefficient', fontsize = 19)
plt.tight_layout()
plt.savefig('note_book_plot/friction inset yield stage .svg', dpi=600, format='svg')
plt.show()

# %%
# friction inset unstable stick-slip stage
fig = plt.figure(figsize=(6*0.5,4*0.5))
plt.rcParams['font.size'] = 12
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(HistoryData_[:, 1] * 1000,  \
         HistoryData_[:, 6],\
         linewidth = 1, color = 'b')
plt.xlim([0.41, 0.59])
plt.ylim([0.2, 0.35])
plt.xticks([0.41, 0.5, 0.59])
plt.yticks([0.2, 0.25, 0.30, 0.35])
# plt.xlabel('Displacement (mm)', fontsize = 19)
# plt.ylabel('Macro friction coefficient', fontsize = 19)
plt.tight_layout()
plt.savefig('note_book_plot/unstable stick-slip stage.svg', dpi=600, format='svg')
plt.show()

# %%
# friction inset stable stick-slip stage
fig = plt.figure(figsize=(6*0.5,4*0.5))
plt.rcParams['font.size'] = 12
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(HistoryData_[:, 1] * 1000,  \
         HistoryData_[:, 6],\
         linewidth = 1, color = 'b')
plt.xlim([3.4, 3.58])
plt.ylim([0.2, 0.35])
plt.xticks([3.4, 3.49, 3.58])
plt.yticks([0.2, 0.25, 0.30, 0.35])
# plt.xlabel('Displacement (mm)', fontsize = 19)
# plt.ylabel('Macro friction coefficient', fontsize = 19)
plt.tight_layout()
plt.savefig('note_book_plot/friction inset stable stick-slip stage.svg', dpi=600, format='svg')
plt.show()

# %%
# plate velocity inset overall

plt.rcParams['font.size'] = 12
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(HistoryData_[:, 1] * 1000,  \
         np.absolute(HistoryData_[:, 8] - HistoryData_[:, 10]) / 2,\
         linewidth = 1, color = 'b')
plt.xlim([-0.1, 4])
plt.ylim([-0.1, 2.5])
plt.xlabel('Displacement (mm)', fontsize = 14)
plt.ylabel('Plate differential velocity (m/s)', fontsize = 14)
plt.tight_layout()
plt.savefig('note_book_plot/plate velocity inset overall.svg', dpi=600, format='svg')
plt.show()

# %%
# plate velocity inset linear stage

fig = plt.figure(figsize=(6*0.5,4*0.5))
plt.rcParams['font.size'] = 12
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(HistoryData_[:, 1] * 1000,  \
         np.absolute(HistoryData_[:, 8] - HistoryData_[:, 10]) / 2,\
         linewidth = 1, color = 'b')
plt.xlim([0.005, 0.185])
plt.ylim([-0.1, 2.5])
plt.xticks([0.005,0.095, 0.185])
plt.yticks([0, 0.5, 1, 1.5, 2, 2.5])
# plt.xlabel('Displacement (mm)', fontsize = 19)
# plt.ylabel('Average plate velocity (m/s)', fontsize = 19)
plt.tight_layout()
plt.savefig('note_book_plot/plate velocity inset linear stage.svg', dpi=600, format='svg')
plt.show()

# %%
# plate velocity inset yield stage

fig = plt.figure(figsize=(6*0.5,4*0.5))
plt.rcParams['font.size'] = 12
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(HistoryData_[:, 1] * 1000,  \
         np.absolute(HistoryData_[:, 8] - HistoryData_[:, 10]) / 2,\
         linewidth = 1, color = 'b')

plt.ylim([-0.1, 2.5])
plt.yticks([0, 0.5, 1, 1.5, 2, 2.5])
plt.xlim([0.25, 0.43])
plt.xticks([0.25, 0.34, 0.43])
# plt.xlabel('Displacement (mm)', fontsize = 19)
# plt.ylabel('Average plate velocity (m/s)', fontsize = 19)
plt.tight_layout()
plt.savefig('note_book_plot/plate velocity inset yield stage.svg', dpi=600, format='svg')
plt.show()

# %%
# plate velocity inset unstable stick-slip stage

fig = plt.figure(figsize=(6*0.5,4*0.5))
plt.rcParams['font.size'] = 12
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(HistoryData_[:, 1] * 1000,  \
         np.absolute(HistoryData_[:, 8] - HistoryData_[:, 10]) / 2,\
         linewidth = 1, color = 'b')

plt.ylim([-0.1, 2.5])
plt.xlim([0.41, 0.59])
plt.xticks([0.41, 0.5, 0.59])
plt.yticks([0, 0.5, 1, 1.5, 2, 2.5])

# plt.xlabel('Displacement (mm)', fontsize = 19)
# plt.ylabel('Average plate velocity (m/s)', fontsize = 19)
plt.tight_layout()
plt.savefig('note_book_plot/plate velocity inset unstable stick-slip stage.svg', dpi=600, format='svg')
plt.show()

# %%
# plate velocity inset stable stick-slip stage
fig = plt.figure(figsize=(6*0.5,4*0.5))
plt.rcParams['font.size'] = 12
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(HistoryData_[:, 1] * 1000,  \
         np.absolute(HistoryData_[:, 8] - HistoryData_[:, 10]) / 2,\
         linewidth = 1, color = 'b')

plt.ylim([-0.1, 2.5])
plt.xlim([3.4, 3.58])
plt.xticks([3.4, 3.49, 3.58])
plt.yticks([0, 0.5, 1, 1.5, 2, 2.5])
# plt.xlabel('Displacement (mm)', fontsize = 19)
# plt.ylabel('Average plate velocity (m/s)', fontsize = 19)
plt.tight_layout()
plt.savefig('note_book_plot/plate velocity inset stable stick-slip stage.svg', dpi=600, format='svg')
plt.show()
