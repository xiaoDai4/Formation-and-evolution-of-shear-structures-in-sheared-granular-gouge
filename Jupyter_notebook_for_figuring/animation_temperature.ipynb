# %%
#  import package and data, set wd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.image as mgimg
from matplotlib.animation import FuncAnimation
import numpy as np
from IPython.display import HTML
import os
import math
import pandas as pd

# set work directory
os.chdir('C:/Users/daizh/sheared_granular_gouge/20231116_FifthRun3_Stage4/PythonFile_CalculateGranularQuantity')

# set the animation range
index_ani_ = [int(i_) for i_ in range(250, 601)]

# %%
nframes_ = len(index_ani_)
# plt.subplots_adjust(top=1, bottom=0, left=0, right=1)


def animate(i_):
    plt.clf()
    plt.axis('off')
    im = 'note_book_plot/temperature_animation/granular_temperature_at_%d.png' % index_ani_[i_]
    print(im)
    img = mgimg.imread(im)
    ani_ = plt.imshow(img)
    

anim = FuncAnimation(plt.gcf(), animate, frames=nframes_, 
                     interval= 100)
anim.save('note_book_plot/animation of a slip event in stage IV (stable stick-slip stage).mp4', dpi=600)
# Out:
# note_book_plot/temperature_animation/granular_temperature_at_250.png
# note_book_plot/temperature_animation/granular_temperature_at_250.png
# note_book_plot/temperature_animation/granular_temperature_at_251.png
# note_book_plot/temperature_animation/granular_temperature_at_252.png
# note_book_plot/temperature_animation/granular_temperature_at_253.png
# note_book_plot/temperature_animation/granular_temperature_at_254.png
# note_book_plot/temperature_animation/granular_temperature_at_255.png
# note_book_plot/temperature_animation/granular_temperature_at_256.png
# note_book_plot/temperature_animation/granular_temperature_at_257.png
# note_book_plot/temperature_animation/granular_temperature_at_258.png
# note_book_plot/temperature_animation/granular_temperature_at_259.png
# note_book_plot/temperature_animation/granular_temperature_at_260.png
# note_book_plot/temperature_animation/granular_temperature_at_261.png
# note_book_plot/temperature_animation/granular_temperature_at_262.png
# ...
